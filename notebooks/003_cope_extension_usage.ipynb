# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
from satellite import request, ADM2

# %%
with request.reanalysis_era5_land(output="example3", locale="BRA", date="2024-10-22") as ds:
    df = ds.cope.to_dataframe(ADM2.get(code=3304557, adm0="BRA"))
df
# Out:
# 2024-11-01 15:58:10,121 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 15:58:10,122 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 15:58:10,123 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 15:58:10,123 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 15:58:10,123 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 15:58:11,042 INFO Request ID is 888b2051-725a-4561-ae87-2310bab620d0
# 2024-11-01 15:58:11,294 INFO status has been updated to accepted
# 2024-11-01 16:02:33,109 INFO status has been updated to successful
#         date  geocode  temp_max  precip_max  umid_max  pressao_max  temp_med  \
# 0 2024-10-22  3304557   30.8855      1.4735   95.7961        0.992   25.1695
#
#    precip_med  umid_med  pressao_med  temp_min  precip_min  umid_min  \
# 0      0.1854   78.4611       0.9898   20.9851         0.0   52.2234
#
#    pressao_min  precip_tot epiweek
# 0        0.987       1.483  202443

# %%
with request.reanalysis_era5_land(output="example3", locale="BRA", date="2024-10-22") as ds:
    df = ds.cope.to_dataframe(ADM2.filter(adm1=42, adm0="BRA"))
df
# Out:
#           date  geocode  temp_max  precip_max  umid_max  pressao_max  \
# 0   2024-10-22  4200051   26.4615      0.3353   95.2982       0.9141
# 1   2024-10-22  4200101   26.6441      0.6386   91.3099       0.9059
# 2   2024-10-22  4200200   27.2669      1.7119   98.0394       0.9287
# 3   2024-10-22  4200309   27.8666      1.3024   98.2263       0.9485
# 4   2024-10-22  4200408   24.9275      0.5899   96.8109       0.8820
# ..         ...      ...       ...         ...       ...          ...
# 290 2024-10-22  4219507   27.5360      0.4588   86.7889       0.9211
# 291 2024-10-22  4219606   27.5782      0.3833   89.8519       0.9243
# 292 2024-10-22  4219705   28.2923      0.3487   87.1422       0.9322
# 293 2024-10-22  4219853   27.1283      0.1433   91.8135       0.9253
# 294 2024-10-22  4220000   27.5748      0.0650   91.3934       0.9955
#
#      temp_med  precip_med  umid_med  pressao_med  temp_min  precip_min  \
# 0     21.4268      0.1302   79.5940       0.9127   17.7033      0.0000
# 1     21.9506      0.1941   77.5813       0.9044   17.7171      0.0035
# 2     21.3641      0.5652   83.6527       0.9269   17.7844      0.0800
# 3     22.1036      0.4814   83.3668       0.9466   18.7003      0.0267
# 4     20.1539      0.2014   80.8704       0.8807   15.7457      0.0002
# ..        ...         ...       ...          ...       ...         ...
# 290   23.1176      0.1462   72.8344       0.9195   18.9048      0.0000
# 291   23.0372      0.1304   74.3280       0.9226   18.4527      0.0000
# 292   23.6714      0.1273   73.1314       0.9305   19.2526      0.0000
# 293   22.4544      0.0509   76.4135       0.9239   18.1451      0.0000
# 294   23.4180      0.0089   80.8257       0.9942   19.8201      0.0000
#
#      umid_min  pressao_min  precip_tot epiweek
# 0     58.8941       0.9101      1.0412  202443
# 1     61.1932       0.9022      1.5531  202443
# 2     59.0611       0.9236      4.5219  202443
# 3     59.1501       0.9428      3.8510  202443
# 4     59.0135       0.8787      1.6114  202443
# ..        ...          ...         ...     ...
# 290   58.8629       0.9172      1.1692  202443
# 291   58.8921       0.9203      1.0436  202443
# 292   58.7567       0.9281      1.0188  202443
# 293   59.1032       0.9212      0.4073  202443
# 294   67.0609       0.9927      0.0714  202443
#
# [295 rows x 16 columns]

# %%
with request.reanalysis_era5_land(output="example4", locale="ARG", date="2024-10-19") as ds:
    df = ds.cope.to_dataframe(ADM2.filter(adm0="ARG")) # WARNING: too many ADM2 may result in high CPU usage
df
# Out:
# 2024-11-01 16:03:44,968 INFO [2024-09-28T00:00:00] **Welcome to the New Climate Data Store (CDS)!** This new system is in its early days of full operations and still undergoing enhancements and fine tuning. Some disruptions are to be expected. Your
# [feedback](https://jira.ecmwf.int/plugins/servlet/desk/portal/1/create/202) is key to improve the user experience on the new CDS for the benefit of everyone. Thank you.
# 2024-11-01 16:03:44,969 WARNING [2024-09-26T00:00:00] Should you have not yet migrated from the old CDS system to the new CDS, please check our [informative page](https://confluence.ecmwf.int/x/uINmFw) for guidance.
# 2024-11-01 16:03:44,969 INFO [2024-09-26T00:00:00] Watch our [Forum](https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# 2024-11-01 16:03:44,969 INFO [2024-09-16T00:00:00] Remember that you need to have an ECMWF account to use the new CDS. **Your old CDS credentials will not work in new CDS!**
# 2024-11-01 16:03:44,970 WARNING [2024-06-16T00:00:00] CDS API syntax is changed and some keys or parameter names may have also changed. To avoid requests failing, please use the "Show API request code" tool on the dataset Download Form to check you are using the correct syntax for your API request.
# 2024-11-01 16:03:45,637 INFO Request ID is e7e55a97-01c2-4a26-8723-82141a2ee9a2
# 2024-11-01 16:03:45,870 INFO status has been updated to accepted
# 2024-11-01 16:03:48,825 INFO status has been updated to running
# 2024-11-01 16:03:51,324 INFO status has been updated to successful
#           date geocode  temp_max  precip_max  umid_max  pressao_max  temp_med  \
# 0   2024-10-19   02001   25.7262      0.0017   91.2310       1.0030   20.6883
# 1   2024-10-19   02002   25.7262      0.0017   91.2310       1.0030   20.6883
# 2   2024-10-19   02003   25.7262      0.0017   91.2310       1.0030   20.6883
# 3   2024-10-19   02004   25.7889      0.0017   91.8520       1.0030   20.6490
# 4   2024-10-19   02005   25.7262      0.0017   91.2310       1.0030   20.6883
# ..         ...     ...       ...         ...       ...          ...       ...
# 521 2024-10-19   90112   24.7493      7.0158   94.1916       0.8506   18.8480
# 522 2024-10-19   90119   23.7292     12.2212   98.1554       0.8923   19.0133
# 523 2024-10-19   94007   10.3642      1.1037   87.0948       0.9727    8.1233
# 524 2024-10-19   94014    8.7542      4.3105   90.2474       0.9561    6.1764
# 525 2024-10-19   94021   10.9464      2.3659   90.8225       0.9852    7.6822
#
#      precip_med  umid_med  pressao_med  temp_min  precip_min  umid_min  \
# 0        0.0011   75.2292       1.0005   16.4059      0.0000   56.8682
# 1        0.0011   75.2292       1.0005   16.4059      0.0000   56.8682
# 2        0.0011   75.2292       1.0005   16.4059      0.0000   56.8682
# 3        0.0011   75.2658       1.0005   16.2235      0.0000   55.7723
# 4        0.0011   75.2292       1.0005   16.4059      0.0000   56.8682
# ..          ...       ...          ...       ...         ...       ...
# 521      1.0495   76.8690       0.8475   14.7190      0.0995   51.4038
# 522      2.5259   87.0546       0.8891   15.5764      0.4349   68.9264
# 523      0.6779   71.1621       0.9698    6.3777      0.0237   55.8481
# 524      1.0974   78.5380       0.9532    3.9739      0.0028   67.5957
# 525      0.2999   81.1497       0.9837    4.0422      0.0020   67.4429
#
#      pressao_min  precip_tot epiweek
# 0         0.9961      0.0086  202442
# 1         0.9961      0.0086  202442
# 2         0.9961      0.0086  202442
# 3         0.9961      0.0086  202442
# 4         0.9961      0.0086  202442
# ..           ...         ...     ...
# 521       0.8433      8.3962  202442
# 522       0.8844     20.2073  202442
# 523       0.9683      5.4235  202442
# 524       0.9516      8.7793  202442
# 525       0.9810      2.3993  202442
#
# [526 rows x 16 columns]

# %%
ds = request.reanalysis_era5_land("example2", variable=["2m_temperature"], time=["00:00"], locale="BRA", date="2000-01-01/2000-01-15")
ds.cope.adm_ds(ADM2.get(code=3304557, adm0="BRA")).temp_med.plot()
