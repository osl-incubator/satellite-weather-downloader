# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
from satellite.downloader import download_br_netcdf
from satellite.weather import load_dataset
# Out:
# Warning: Input is not a terminal (fd=0).

# %% [markdown]
# ---
#
# ## Basic Usage

# %%
# Downloads the last update date from Copernicus
br_last_update = download_br_netcdf()
# Out:
# 2023-08-07 16:53:51,464 WARNING No date provided, downloading last available date: 2023-07-30

# %%
# Loads the dataset into memory
ds = load_dataset(br_last_update)

# %%
# Extracts information of Rio de Janeiro & São Paulo
ds.copebr.to_dataframe([3304557, 3550308])
# Out:
#         date   temp_max  precip_max   umid_max  pressao_max   temp_med  \
# 0 2023-07-30  21.152313     0.30041  87.090843     1.013742  19.039223
# 0 2023-07-30  19.262421     0.01505  92.743591     1.013351  14.388599
#
#    precip_med   umid_med  pressao_med   temp_min  precip_min   umid_min  \
# 0    0.087582  81.713837     1.012271  17.519226      0.0005  72.319901
# 0    0.007414  84.135612     1.012089  11.754761      0.0000  65.942245
#
#    pressao_min  precip_tot  geocodigo
# 0     1.011043     0.70066    3304557
# 0     1.009744     0.05931    3550308

# %% [markdown]
# ---
#
# ## Date ranges

# %%
# Downloads BR dataset between dates 2023/jan/01 & 2023/feb/01
br_between = download_br_netcdf("2023-01-01", "2023-02-01")

# %%
ds = load_dataset(br_between)
ds.copebr.to_dataframe([3304557, 3550308])
# Out:
#          date   temp_max  precip_max   umid_max  pressao_max   temp_med  \
# 0  2023-01-01  28.611298     3.12800  92.637665     1.003064  25.204868
# 1  2023-01-02  29.972565     1.57566  93.351074     1.001920  25.821037
# 2  2023-01-03  32.171112     0.01402  86.056244     0.997397  27.237656
# 3  2023-01-04  31.644012     1.24125  84.621117     0.995893  27.618412
# 4  2023-01-05  24.221985     1.04915  93.496033     0.998718  23.498684
# ..        ...        ...         ...        ...          ...        ...
# 54 2023-02-24  28.058228     1.89272  97.005310     1.004543  22.642567
# 55 2023-02-25  28.097992     1.07649  92.217499     1.000872  23.735664
# 56 2023-02-26  29.201263     0.07712  93.918289     1.003259  23.842018
# 57 2023-02-27  26.734528     2.03801  96.459724     1.006826  22.710812
# 58 2023-02-28  24.635956     3.82697  94.964096     1.008218  21.168468
#
#     precip_med   umid_med  pressao_med   temp_min  precip_min   umid_min  \
# 0     0.469126  82.269981     1.001414  22.447174     0.00000  69.146835
# 1     0.246625  77.906898     0.999366  22.230316     0.00000  59.107758
# 2     0.002541  71.091240     0.995910  23.381561     0.00000  52.390064
# 3     0.230718  74.430405     0.994690  25.641022     0.00000  56.445282
# 4     0.480956  90.630959     0.997706  22.909393     0.20296  86.908440
# ..         ...        ...          ...        ...         ...        ...
# 54    0.270110  84.039482     1.002152  19.248474     0.00000  62.152145
# 55    0.143413  78.404602     0.999890  20.451080     0.00000  57.734215
# 56    0.017330  78.805908     1.002186  19.830414     0.00000  57.632893
# 57    0.291250  85.964188     1.005448  20.227509     0.00035  71.415459
# 58    0.609559  89.016861     1.007102  19.595123     0.02752  76.990540
#
#     pressao_min  precip_tot  geocodigo
# 0      0.999961     3.75301    3304557
# 1      0.995433     1.97300    3304557
# 2      0.994020     0.02033    3304557
# 3      0.993015     1.84574    3304557
# 4      0.995900     3.84765    3304557
# ..          ...         ...        ...
# 54     0.998646     2.16088    3550308
# 55     0.998688     1.14730    3550308
# 56     1.000693     0.13864    3550308
# 57     1.003936     2.33000    3550308
# 58     1.005473     4.87647    3550308
#
# [118 rows x 15 columns]
