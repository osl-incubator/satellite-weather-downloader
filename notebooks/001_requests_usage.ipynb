# %%
import dotenv
dotenv.load_dotenv() # CDSAPI_TOKEN
# Out:
# True

# %% [markdown]
# ---
#
# ## ERA5 Land (reanalysis)
# ### https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land

# %% [markdown]
# ### Default options:
#
# ```python
# product_type: list[str] = ["reanalysis"]
# variable: list[str] = ["2m_temperature", "total_precipitation", "2m_dewpoint_temperature", "surface_pressure"]
# date: str = str((datetime.now() - timedelta(days=6)).date()) # ISO8601 (YYYY-mm-dd)
# time: list[str] = [
#     "00:00", "03:00", "06:00",
#     "09:00", "12:00", "15:00",
#     "18:00", "21:00",
# ],
# locale: Optional[Literal["BRA", "ARG"]] = None
# area : Optional[Dict[Literal["N", "S", "W", "E"], float]] = None
# format : Literal["grib", "netcdf"] = "netcdf"
# download_format: Literal["zip", "unarchived"] = "zip"
# ```

# %%
from satellite import request

# %%
# Downloads the last update date from Copernicus globalwide
request.reanalysis_era5_land()
# Out:
# <xarray.Dataset> Size: 830MB
# Dimensions:     (valid_time: 8, latitude: 1801, longitude: 3600)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 64B 2024-10-22 ... 2024-10-22T21:...
#   * latitude    (latitude) float64 14kB 90.0 89.9 89.8 ... -89.8 -89.9 -90.0
#   * longitude   (longitude) float64 29kB -180.0 -179.9 -179.8 ... 179.8 179.9
#     expver      (valid_time) <U4 128B ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 207MB ...
#     tp          (valid_time, latitude, longitude) float32 207MB ...
#     d2m         (valid_time, latitude, longitude) float32 207MB ...
#     sp          (valid_time, latitude, longitude) float32 207MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-28T16:44 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# Using the request parameters
request.reanalysis_era5_land("example.zip", variable=["2m_temperature"], time=["00:00"], locale="BRA", date="2000-01-01/2000-01-15")
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:     (valid_time: 15, latitude: 393, longitude: 418)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 120B 2000-01-01 ... 2000-01-15
#   * latitude    (latitude) float64 3kB 5.45 5.35 5.25 ... -33.55 -33.65 -33.75
#   * longitude   (longitude) float64 3kB -74.0 -73.9 -73.8 ... -32.5 -32.4 -32.3
#     expver      (valid_time) <U4 240B ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 10MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-25T14:05 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# Loads the dataset into memory

from satellite import DataSet
with DataSet.from_netcdf("example.zip") as ds:
    print(ds)
# Out:
# <xarray.Dataset> Size: 10MB
# Dimensions:     (valid_time: 15, latitude: 393, longitude: 418)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 120B 2000-01-01 ... 2000-01-15
#   * latitude    (latitude) float64 3kB 5.45 5.35 5.25 ... -33.55 -33.65 -33.75
#   * longitude   (longitude) float64 3kB -74.0 -73.9 -73.8 ... -32.5 -32.4 -32.3
#     expver      (valid_time) <U4 240B ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 10MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-25T14:05 GRIB to CDM+CF via cfgrib-0.9.1...
