# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
from satellite.downloader import download_netcdf
from satellite.weather import load_dataset

# %% [markdown]
# ---
#
# ## Basic Usage

# %%
# Downloads the last update date from Copernicus
last_update = download_netcdf("filename")
# Out:
# 2023-08-23 15:17:00,987 WARNING No date provided, downloading last available date: 2023-08-15
# 2023-08-23 15:17:01,948 INFO Welcome to the CDS
# 2023-08-23 15:17:01,949 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels
# 2023-08-23 15:17:02,345 INFO Request is completed
# 2023-08-23 15:17:02,346 INFO Downloading https://download-0000-clone.copernicus-climate.eu/cache-compute-0000/cache/data4/adaptor.mars.internal-1692812841.1435375-29981-14-ede6c326-74bd-44bb-a885-9ad634c2f245.nc to /home/bida/copernicus_data/filename.nc (63.4M)
# 2023-08-23 15:17:16,870 INFO Download rate 4.4M/s

# %%
# Loads the dataset into memory
ds = load_dataset(last_update)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 8)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2023-08-15 ... 2023-08-15T21:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
#     tp         (time, latitude, longitude) float32 ...
#     d2m        (time, latitude, longitude) float32 ...
#     msl        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-08-23 17:47:21 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
# ds inherits the methods from Xarray dataset
df = ds.to_dataframe()

# %% [markdown]
# ---
#
# ## Date ranges
#
# !WARNING: Not providing latitude and longitude (globalwide) will download big files, specially when providing a date range

# %%
# Downloads dataset between dates 2023/jan/01 & 2023/jan/02
date_range = download_netcdf("date_range", "2023-01-01", "2023-01-02")
# Out:
# 2023-08-23 15:17:18,164 INFO Welcome to the CDS
# 2023-08-23 15:17:18,164 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels
# 2023-08-23 15:17:18,494 INFO Request is completed
# 2023-08-23 15:17:18,496 INFO Downloading https://download-0021.copernicus-climate.eu/cache-compute-0021/cache/data1/adaptor.mars.internal-1692814218.2363923-24601-4-94dcf4b3-cd35-40df-88d3-266cd847fbde.nc to /home/bida/copernicus_data/date_range.nc (126.7M)
# 2023-08-23 15:17:58,916 INFO Download rate 3.1M/s

# %%
ds = load_dataset(date_range)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 721, time: 16)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * time       (time) datetime64[ns] 2023-01-01 ... 2023-01-02T21:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
#     tp         (time, latitude, longitude) float32 ...
#     d2m        (time, latitude, longitude) float32 ...
#     msl        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-08-23 18:10:19 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
