# %%
from satellite.weather.orm.models import ADM0, ADM1, ADM2

# %%
df = ADM0.get(code="ARG").to_dataframe()
df
# Out:
#   code       name                                           geometry
# 0  ARG  Argentina  MULTIPOLYGON (((-68.24164 -54.8755, -68.24108 ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df = ADM1.filter(code=10, adm0="ARG")[0].to_dataframe()
df
# Out:
#   code       name adm0                                           geometry
# 0   10  Catamarca  ARG  POLYGON ((-65.5949 -29.70813, -65.60121 -29.69...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df = ADM2.get(code="02001", adm0="ARG").to_dataframe()
df
# Out:
#     code       name adm0 adm1  \
# 0  02001  Comuna 01  ARG   02
#
#                                             geometry
# 0  MULTIPOLYGON (((-58.36801 -34.57821, -58.36798...

# %%
df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd

df = pd.concat([adm2.to_dataframe() for adm2 in ADM2.filter(adm0="ARG")]).reset_index(drop=True)
df
# Out:
#       code                     name adm0 adm1  \
# 0    02001                Comuna 01  ARG   02
# 1    02002                Comuna 02  ARG   02
# 2    02003                Comuna 03  ARG   02
# 3    02004                Comuna 04  ARG   02
# 4    02005                Comuna 05  ARG   02
# ..     ...                      ...  ...  ...
# 521  90112                  Trancas  ARG   90
# 522  90119              Yerba Buena  ARG   90
# 523  94007               Río Grande  ARG   94
# 524  94014                  Ushuaia  ARG   94
# 525  94021  Islas del Atlantico Sur  ARG   94
#
#                                               geometry
# 0    MULTIPOLYGON (((-58.36801 -34.57821, -58.36798...
# 1    MULTIPOLYGON (((-58.3944 -34.59968, -58.39471 ...
# 2    MULTIPOLYGON (((-58.4103 -34.59809, -58.40943 ...
# 3    MULTIPOLYGON (((-58.35987 -34.62558, -58.35978...
# 4    MULTIPOLYGON (((-58.41566 -34.59786, -58.41463...
# ..                                                 ...
# 521  MULTIPOLYGON (((-65.35613 -26.05868, -65.35481...
# 522  MULTIPOLYGON (((-65.3045 -26.73503, -65.3051 -...
# 523  MULTIPOLYGON (((-68.60342 -54.35946, -68.60803...
# 524  MULTIPOLYGON (((-67.39809 -54.90305, -67.39726...
# 525  MULTIPOLYGON (((-59.061 -52.42365, -59.05823 -...
#
# [526 rows x 5 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df = pd.concat([adm.to_dataframe() for adm in ADM2.filter(adm1="10", adm0="ARG")]).reset_index(drop=True)
df
# Out:
#      code                      name adm0 adm1  \
# 0   10007                    Ambato  ARG   10
# 1   10014                   Ancasti  ARG   10
# 2   10021                 Andalgalá  ARG   10
# 3   10028  Antofagasta de la Sierra  ARG   10
# 4   10035                     Belén  ARG   10
# 5   10042                   Capayán  ARG   10
# 6   10049                   Capital  ARG   10
# 7   10056                   El Alto  ARG   10
# 8   10063       Fray Mamerto Esquiú  ARG   10
# 9   10070                    La Paz  ARG   10
# 10  10077                    Paclin  ARG   10
# 11  10084                     Poman  ARG   10
# 12  10091               Santa María  ARG   10
# 13  10098                Santa Rosa  ARG   10
# 14  10105                 Tinogasta  ARG   10
# 15  10112               Valle Viejo  ARG   10
#
#                                              geometry
# 0   MULTIPOLYGON (((-65.93497 -27.6204, -65.92481 ...
# 1   MULTIPOLYGON (((-65.68453 -28.82393, -65.68443...
# 2   MULTIPOLYGON (((-66.36768 -27.19871, -66.34495...
# 3   MULTIPOLYGON (((-67.87681 -25.23707, -67.8646 ...
# 4   MULTIPOLYGON (((-66.74106 -28.02534, -66.76509...
# 5   MULTIPOLYGON (((-65.52313 -29.60363, -65.53742...
# 6   MULTIPOLYGON (((-65.80755 -28.26975, -65.80495...
# 7   MULTIPOLYGON (((-65.39157 -28.16964, -65.39197...
# 8   MULTIPOLYGON (((-65.66517 -28.41778, -65.66561...
# 9   MULTIPOLYGON (((-65.21049 -28.60281, -65.21035...
# 10  MULTIPOLYGON (((-65.7205 -27.80226, -65.71989 ...
# 11  MULTIPOLYGON (((-66.0882 -27.80252, -66.08823 ...
# 12  MULTIPOLYGON (((-66.15731 -26.41698, -66.15836...
# 13  MULTIPOLYGON (((-65.17189 -27.9459, -65.1708 -...
# 14  MULTIPOLYGON (((-69.08433 -27.79225, -69.08148...
# 15  MULTIPOLYGON (((-65.66518 -28.41782, -65.66533...

# %%
df.plot()
# Out:
# <Axes: >
